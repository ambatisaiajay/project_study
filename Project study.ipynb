# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <B> AMBATI SAI AJAY KUMAR
#
# QUALITY ANALYST

# %% [markdown]
# *I am interested in data science because it helps us to gives a better decision choice with a solid data support*

# %% [markdown]
# ## Code below is to add two numbers ##

# %%
1+1
# Out:
# 2

# %% [markdown]
# - data science languages
#     - SQL
#     - R
#     - Python
#
#   States of india
#      1. Delhi
#      2. Hyderabad
#      3.Mumbai

# %% [markdown]
# ![india-map-2019.jpg](attachment:india-map-2019.jpg)
